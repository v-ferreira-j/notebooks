# %%
# ignore
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
#
#
#
# defina a função usada como modelo
def func(x, a, b):
    return b - np.exp(-a*x)
#
#
#
# importe os dados
xdata = np.arange(2,45)
ydata = [0.60205999133, 0.845098044, 1.0413926855, 1.2552725056, 1.3979400097, 1.5314789178, 1.6627578329, 1.77085201210, 1.88649072512, 2.05690485113, 2.13353890814, 2.21218760415, 2.30319605716, 2.38381536617, 2.5105450118, 2.54654266319, 2.64836001120, 2.68663626921, 2.75127910422, 2.83632411623, 2.91381385224, 2.97954837525, 3.02857125326, 3.05690485127, 3.08742645728, 3.12319807529, 3.18525876530, 3.24477176131, 3.28936595232, 3.33061666733, 3.37309598734, 3.39128804935, 3.41279642936, 3.43790903637, 3.4632956138, 3.52022143639, 3.56466606440, 3.60691852641, 3.63052957142, 3.65734273743, 3.70440792744, 3.74123041145, 3.770925615]
#
#
#
# execute o ajuste da curva
popt, pcov = curve_fit(func, xdata, ydata)
#
#
# desenho comparando o original e ajustado
#
plt.plot(xdata, ydata, 'b-', label='data')
plt.plot(xdata, func(xdata, *popt), 'r-', label='fit: a=%5.3f, b=%5.3f' % tuple(popt))
plt.xlabel('t')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
# ignore
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
#
#
#
# defina a função usada como modelo
def func(x, a, b):
    return a*np.arctan(x*b)
#
#
#
# importe os dados
xdata = np.arange(2,45)
ydata = [0.60205999133, 0.845098044, 1.0413926855, 1.2552725056, 1.3979400097, 1.5314789178, 1.6627578329, 1.77085201210, 1.88649072512, 2.05690485113, 2.13353890814, 2.21218760415, 2.30319605716, 2.38381536617, 2.5105450118, 2.54654266319, 2.64836001120, 2.68663626921, 2.75127910422, 2.83632411623, 2.91381385224, 2.97954837525, 3.02857125326, 3.05690485127, 3.08742645728, 3.12319807529, 3.18525876530, 3.24477176131, 3.28936595232, 3.33061666733, 3.37309598734, 3.39128804935, 3.41279642936, 3.43790903637, 3.4632956138, 3.52022143639, 3.56466606440, 3.60691852641, 3.63052957142, 3.65734273743, 3.70440792744, 3.74123041145, 3.770925615]
#
#
#
# execute o ajuste da curva
popt, pcov = curve_fit(func, xdata, ydata)
#
#
# desenho comparando o original e ajustado
#
plt.plot(xdata, ydata, 'b-', label='data')
plt.plot(xdata, func(xdata, *popt), 'r-', label='fit: a=%5.3f, b=%5.3f' % tuple(popt))
plt.xlabel('t')
plt.ylabel('y')
plt.legend()
plt.show()
